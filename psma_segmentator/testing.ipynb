# %%
import sys
sys.path.append("..")
from dicom import convertPET2SUV
#from python_api import psmasegmentator
import torch
import warnings
import os
import SimpleITK as sitk
from psmasegmentator.config import get_psmasegmentator_dir, setup_psmasegmentator

# %% [markdown]
# # Testing the full PSMA Segmentator pipeline

# %%
import sys
import os
from pathlib import Path
import SimpleITK as sitk
import numpy as np
from psmasegmentator.download_weights import download_fold_weights_via_api
from psmasegmentator.inference import nnUNet_predict_image
from psmasegmentator.config import get_psmasegmentator_dir, setup_psmasegmentator


def psmasegmentator (pet_dir=None, 
                     ct_dir = None,
                     output_dir=None):
    """
    Runs the full PSMA PET segmentation pipeline.

    Args:
        input_dir (str): Directory containing PSMA PET and CT files.
        output_dir (str): Directory to save the segmentation results.
        file_format (str): Input file format, either "dicom" or "nifti". Defaults to "dicom".
        suv_threshold (float): SUV threshold for segmentation refinement. Defaults to 3.

    """
    
    weights_dir = setup_psmasegmentator()

    download_fold_weights_via_api(output_dir = weights_dir)

    nnUNet_predict_image(weights_dir, pet_dir, ct_dir, output_dir,
                         device='cuda', step_size=0.5, use_tta=True, verbose=False)

# %%
pet_input = '/home/galaxypc/Documents/Jake/test2predict/PSMA_Repeatability_001_0000.nii.gz'
ct_input = '/home/galaxypc/Documents/Jake/test2predict/PSMA_Repeatability_001_0001.nii.gz'
output_path = '/home/galaxypc/Documents/Jake/test_output_prediction'
psmasegmentator(pet_dir=pet_input, ct_dir=ct_input, output_dir=output_path)
# Out:
# Setting up psmasegmentator version 0.0.1
# ...
# File downloaded to /home/galaxypc/.psmasegmentator/0.0.1/results/dataset.json
# Downloaded dataset.json to /home/galaxypc/.psmasegmentator/0.0.1/results/dataset.json
# ...
# File downloaded to /home/galaxypc/.psmasegmentator/0.0.1/results/plans.json
# Downloaded plans.json to /home/galaxypc/.psmasegmentator/0.0.1/results/plans.json
# ...
# File downloaded to /home/galaxypc/.psmasegmentator/0.0.1/results/fold_0.zip
# Downloaded fold 0 weights to /home/galaxypc/.psmasegmentator/0.0.1/results/fold_0.zip
# Extracting fold 0 weights to /home/galaxypc/.psmasegmentator/0.0.1/results/fold_0...
# Extraction complete for fold 0.
# Removed temporary zip file for fold 0: /home/galaxypc/.psmasegmentator/0.0.1/results/fold_0.zip
# ...
# File downloaded to /home/galaxypc/.psmasegmentator/0.0.1/results/fold_1.zip
# Downloaded fold 1 weights to /home/galaxypc/.psmasegmentator/0.0.1/results/fold_1.zip
# ...

# %%
weights_dir = setup_psmasegmentator()
weights_dir
# Out:
# Setting up psmasegmentator version 0.0.1
# PosixPath('/home/galaxypc/.psmasegmentator/0.0.1/results')

# %%
weights_dir = '/Users/jakekendrick/Desktop/nnUNetTrainer__nnUNetPlans__3d_fullres_resenc/'
os.environ["nnUNet_raw"] = str(weights_dir)
os.environ["nnUNet_preprocessed"] = str(weights_dir)
os.environ["nnUNet_results"] = str(weights_dir)
from nnunetv2.inference.predict_from_raw_data import nnUNetPredictor

# %% [markdown]
# # Paths to the model folder and input/output directories
# model_folder = weights_dir
# input_folder = '/Users/jakekendrick/Desktop/test_inference_file'         # Replace with the path containing your input images
# output_folder = '/Users/jakekendrick/Desktop/test_inference_file_output'  # Replace with the path to save predictions
# os.makedirs(output_folder, exist_ok=True)
#
# # Configuration for the predictor
# device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# import multiprocessing
# torch.set_num_threads(multiprocessing.cpu_count())
# tile_step_size = 0.5
# use_mirroring = True
# checkpoint_name = "checkpoint_final.pth"
#
# # Initialize nnUNetPredictor
# predictor = nnUNetPredictor(
#     tile_step_size=tile_step_size,
#     use_gaussian=True,
#     use_mirroring=use_mirroring,
#     perform_everything_on_device=True,
#     device=device,
#     verbose=True,
#     allow_tqdm=True
# )

# %%
print("Initializing model...")
predictor.initialize_from_trained_model_folder(
    model_training_output_dir=model_folder,
    use_folds=None,  # Automatically detect available folds
    checkpoint_name=checkpoint_name
)
# Out:
# Initializing model...
# use_folds is None, attempting to auto detect available folds
# found the following folds: [0, 1, 2, 3, 4]
# FOUND IT: <class 'dynamic_network_architectures.architectures.unet.ResidualEncoderUNet'>

# %%
# Perform predictions
print("Starting predictions...")
predictor.predict_from_files(
    list_of_lists_or_source_folder=input_folder,
    output_folder_or_list_of_truncated_output_files=output_folder,
    save_probabilities=False,
    overwrite=True,
    num_processes_preprocessing=6,
    num_processes_segmentation_export=4
)
# Out:
# Starting predictions...
# There are 1 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 1 cases that I would like to predict
#
# Predicting PSMA_Repeatability_001:
# perform_everything_on_device: False
# Input shape: torch.Size([2, 191, 551, 192])
# step_size: 0.5
# mirror_axes: (0, 1, 2)
# n_steps 64, image size is torch.Size([191, 551, 192]), tile_size [80, 224, 80], tile_step_size 0.5
# steps:
# [[0, 37, 74, 111], [0, 109, 218, 327], [0, 37, 75, 112]]
# move image to device cpu
# preallocating results arrays on device cpu
#   2%|▏         | 1/64 [01:39<1:44:32, 99.56s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 3
#       1 # Perform predictions
#       2 print("Starting predictions...")
# ----> 3 predictor.predict_from_files(
#       4     list_of_lists_or_source_folder=input_folder,
# ...

# %%
output_dir = '/home/galaxypc/Desktop/nnunet_download' 
from download_weights import download_fold_weights_via_api

download_fold_weights_via_api(
    output_dir=output_dir
)
# Out:
# ...
# File downloaded to /home/galaxypc/Desktop/nnunet_download/dataset.json
# Downloaded dataset.json to /home/galaxypc/Desktop/nnunet_download/dataset.json
# Fold 0 already exists. Skipping download.
# Fold 1 already exists. Skipping download.
# Fold 2 already exists. Skipping download.
# Fold 3 already exists. Skipping download.
# Fold 4 already exists. Skipping download.

# %%
model_folder = '/home/galaxypc/Desktop/nnunet_download'
os.environ["nnUNet_raw"] = str(model_folder)
os.environ["nnUNet_preprocessed"] = str(model_folder)
os.environ["nnUNet_results"] = str(model_folder)
from inference import nnUNet_predict_image

# %%
pet_input = '/home/galaxypc/Documents/Jake/test2predict/PSMA_Repeatability_001_0000.nii.gz'
ct_input = '/home/galaxypc/Documents/Jake/test2predict/PSMA_Repeatability_001_0001.nii.gz'
output_path = '/home/galaxypc/Documents/Jake/test_output_prediction'
#output_path = ''

#Run the predict_image function
my_segmentation = nnUNet_predict_image(model_folder, pet_input, ct_input, output_path,
                         device='cuda', step_size=0.5, use_tta=True, verbose=False)
# Out:
# use_folds is None, attempting to auto detect available folds
# found the following folds: [0, 1, 2, 3, 4]
# ...

# %%
#Check if the output mask is the same as the other one predicted.
software_prediction = sitk.ReadImage(output_path + '/PSMA01.nii.gz')
original_prediction = sitk.ReadImage('/media/galaxypc/Jake_Extern/nnUnet/nnUNet_raw/Dataset703_FS_SCGH_Train/PSMA_Repeatability_TS_Pred/PSMA_Repeatability_001.nii.gz')

# %%
#test if the two images have the same positive voxels
software_prediction_array = sitk.GetArrayFromImage(software_prediction)
original_prediction_array = sitk.GetArrayFromImage(original_prediction)

#Check if the two images have the same positive voxels
assert (software_prediction_array == original_prediction_array).all()

# %% [markdown]
# # Inference Testing

# %%
model_folder = '/home/galaxypc/Documents/Jake/nnUNetTrainer__nnUNetPlans__3d_fullres_resenc'
os.environ["nnUNet_raw"] = str(model_folder)
os.environ["nnUNet_preprocessed"] = str(model_folder)
os.environ["nnUNet_results"] = str(model_folder)
from inference import nnUNet_predict_image

# %%
model_folder = '/home/galaxypc/Documents/Jake/nnUNetTrainer__nnUNetPlans__3d_fullres_resenc'
pet_input = '/home/galaxypc/Documents/Jake/test2predict/PSMA_Repeatability_001_0000.nii.gz'
ct_input = '/home/galaxypc/Documents/Jake/test2predict/PSMA_Repeatability_001_0001.nii.gz'
output_path = '/home/galaxypc/Documents/Jake/test_output_prediction'
#output_path = ''

#Run the predict_image function
my_segmentation = nnUNet_predict_image(model_folder, pet_input, ct_input, output_path,
                         device='cuda', step_size=0.5, use_tta=True, verbose=False)
# Out:
# use_folds is None, attempting to auto detect available folds
# found the following folds: [0, 1, 2, 3, 4]
# ...

# %%
my_segmentation
# Out:
# [None]

# %%
#Check if the output mask is the same as the other one predicted.
software_prediction = sitk.ReadImage(output_path + '/PSMA01.nii.gz')
original_prediction = sitk.ReadImage('/media/galaxypc/Jake_Extern/nnUnet/nnUNet_raw/Dataset703_FS_SCGH_Train/PSMA_Repeatability_TS_Pred/PSMA_Repeatability_001.nii.gz')

# %%
#test if the two images have the same positive voxels
software_prediction_array = sitk.GetArrayFromImage(software_prediction)
original_prediction_array = sitk.GetArrayFromImage(original_prediction)

#Check if the two images have the same positive voxels
assert (software_prediction_array == original_prediction_array).all()

# %%
#Get the number of positive voxel values in both images
software_positive = sitk.GetArrayFromImage(software_prediction).sum()
original_positive = sitk.GetArrayFromImage(original_prediction).sum()

#Print
print(f"Software prediction has {software_positive} positive voxels")
print(f"Original prediction has {original_positive} positive voxels")
# Out:
# Software prediction has 359 positive voxels
# Original prediction has 359 positive voxels

# %%
from pathlib import Path
def get_psmasegmentator_dir(version):
    if "PSMA_SEGMENTATOR_HOME" in os.environ:
        base_dir = Path(os.environ["PSMA_SEGMENTATOR_HOME"])
    else:
        base_dir = Path.home() / ".psmasegmentator"
    return base_dir / version


def setup_psmasegmentator():
    current_version = __version__
    version_dir = get_versioned_psmasegmentator_dir(current_version)
    weights_dir = version_dir / "nnunet" / "results"
    weights_dir.mkdir(parents=True, exist_ok=True)

    os.environ["nnUNet_raw"] = str(weights_dir)
    os.environ["nnUNet_preprocessed"] = str(weights_dir)
    os.environ["nnUNet_results"] = str(weights_dir)

    print(f"PSMASegmentator setup complete for version {current_version}. Weights directory: {weights_dir}")
    return weights_dir

# %%
get_psmasegmentator_dir('v0.0.1')
# Out:
# PosixPath('/home/galaxypc/.psmasegmentator/v0.1.1')

# %%
import pkg_resources
my_version = pkg_resources.get_distribution('psma-segmentator').version
my_version
# Out:
# '0.1.0'

# %%
from importlib.metadata import version
__version__ = version("psma-segmentator")
__version__
# Out:
# '0.0.1'
